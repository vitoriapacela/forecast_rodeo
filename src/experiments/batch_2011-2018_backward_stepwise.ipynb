# %% [markdown]
# # Batch 2011-2018 backward stepwise
#
# Generate MultiLLR (local linear regression with multitask model selection) forecasts for all dates, 2011-2018, using the batch cluster or, optionally, local sequential execution.

# %%
# Autoreload packages that are modified
# %load_ext autoreload
# %autoreload 2

# Load relevant packages
import numpy as np
import pandas as pd
from sklearn import *
import sys
import subprocess
from datetime import datetime, timedelta
import netCDF4
import time
from functools import partial
import os

if os.path.basename(os.getcwd()) == "experiments":
    os.chdir(os.path.join("..",".."))

# Adds 'experiments' folder to path to load experiments_util
sys.path.insert(0, 'src/experiments')
# Load general utility functions
from experiments_util import *
# Load functionality for fitting and predicting
from fit_and_predict import *
# Load functionality for evaluation
from skill import *
# Load functionality for stepwise regression
from stepwise_util import *

# %%
#
# Choose experiment parameters
#
gt_id = "contest_precip" # "contest_precip" or "contest_tmp2m"
target_horizon = "56w" # "34w" or "56w"
margin_in_days = 56
criterion = "mean"

# If run_locally is False, forecast generation jobs for each target date 
# are submitted to a batch cluster using batch_script (recommended)
# If run_locally is True, forecast generation for each target data is 
# executed locally and sequentially and the setting of batch_script is irrelevant
run_locally = False
# Shell script for submitting batch job to cluster; please change to your personal 
# batch cluster submission script.
# Usage for our script is:
#   src/batch/quick_sbatch_python script.py\ script_arg1\ script_arg2 num_cores mem
batch_script = 'src/batch/quick_sbatch_python.sh'
num_cores = 16
mem = "20GB"

contest_id = get_contest_id(gt_id, target_horizon)

#
# Create list of submission dates in YYYYMMDD format
#
submission_dates = [datetime(y,4,18)+timedelta(14*i) for y in range(2011,2018) for i in range(26)]
submission_dates = ['{}{:02d}{:02d}'.format(date.year, date.month, date.day) for date in submission_dates]

# %%
#
# Generate forecasts for each date by submitting batch job or executing locally
#
fitting_script = 'src/experiments/2011-2018_backward_stepwise.py'
for submission_date_str in submission_dates:
    # Load result file name for checking convergence for this submission date
    file_name = default_result_file_names(
        gt_id = gt_id, 
        target_horizon = target_horizon, 
        margin_in_days = margin_in_days,
        criterion = criterion,
        submission_date_str = submission_date_str,
        procedure = "backward_stepwise",
        hindcast_folder = False,
        hindcast_features = False,
        use_knn1 = False)["converged"]
    file_name = file_name.replace("contest_period", "2011-2018")
    # Only run job if result file does not yet exist
    if not os.path.exists(file_name):        
        if run_locally:
            # Execute command locally
            cmd = "{} {} {} {} {} {} {} {} {}".format(
                "python", fitting_script, 
                gt_id, target_horizon,  
                margin_in_days, criterion,
                False, submission_date_str, num_cores)
        else:
            # Submit batch job
            cmd = r"""{} {}\ {}\ {}\ {}\ {}\ {}\ {}\ {} {} {}""".format(
                batch_script, fitting_script, 
                gt_id, target_horizon, 
                margin_in_days, criterion,
                False,
                submission_date_str, num_cores,
                num_cores, mem)
        print(cmd)
        os.system(cmd)
# Out:
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110418 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110502 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110516 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110530 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110613 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110627 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110711 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110725 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110808 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110822 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110905 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20110919 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20111003 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20111017 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20111031 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20111114 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20111128 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20111212 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20111226 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120109 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120123 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120206 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120220 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120305 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120319 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120402 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120418 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120502 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120516 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120530 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120613 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120627 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120711 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120725 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120808 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120822 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120905 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20120919 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20121003 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20121017 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20121031 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20121114 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20121128 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20121212 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20121226 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130109 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130123 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130206 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130220 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130306 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130320 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130403 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130418 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130502 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130516 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130530 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130613 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130627 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130711 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130725 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130808 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130822 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130905 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20130919 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20131003 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20131017 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20131031 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20131114 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20131128 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20131212 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20131226 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140109 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140123 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140206 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140220 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140306 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140320 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140403 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140418 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140502 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140516 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140530 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140613 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140627 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140711 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140725 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140808 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140822 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140905 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20140919 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20141003 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20141017 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20141031 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20141114 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20141128 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20141212 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20141226 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150109 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150123 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150206 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150220 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150306 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150320 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150403 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150418 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150502 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150516 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150530 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150613 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150627 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150711 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150725 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150808 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150822 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150905 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20150919 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20151003 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20151017 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20151031 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20151114 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20151128 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20151212 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20151226 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160109 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160123 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160206 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160220 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160305 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160319 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160402 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160418 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160502 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160516 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160530 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160613 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160627 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160711 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160725 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160808 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160822 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160905 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20160919 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20161003 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20161017 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20161031 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20161114 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20161128 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20161212 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20161226 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170109 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170123 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170206 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170220 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170306 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170320 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170403 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170418 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170502 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170516 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170530 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170613 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170627 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170711 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170725 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170808 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170822 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170905 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20170919 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20171003 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20171017 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20171031 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20171114 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20171128 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20171212 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20171226 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20180109 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20180123 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20180206 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20180220 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20180306 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20180320 16
# python src/experiments/2011-2018_backward_stepwise.py contest_precip 56w 56 mean False 20180403 16
